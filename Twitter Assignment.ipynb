# %%
from tweepy import OAuthHandler
from tweepy import API
from tweepy import Cursor
from datetime import datetime, date, time, timedelta
from collections import Counter
import sys,csv
import tweepy as tw
import pandas as pd
import re 
import tweepy 
from textblob import TextBlob
# Out:
# C:\Users\Aswin\Anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %%
CONSUMER_KEY = 'L2UvKGZtWrAeQAibbuk3I6Yjt'
CONSUMER_SECRET = 'RzyZZw4FCdokahW3Ft9xRAHXdEV2McAvafm50M7fLnM1xy8mIs'
ACCESS_TOKEN = '3029741363-kJvrtCFpziKBIM1PsAd7wiRREHl7vwhBAlM10yB'
ACCESS_TOKEN_SECRET = 'hkolCNEKvMFYj97YqwZsNvVP4zEhPfqVGfFv54C4Nv5aC'


auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
def clean_tweet(tweet):
    #print("CLEANED TWEET = ",' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()))
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
    
def get_tweet_sentiment(tweet):
        analysis = TextBlob(clean_tweet(tweet))
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'
        
def get_tweets(username):
        Labled_tweet = []
        Unlabled_Raw_tweet = []
        tweets = tw.Cursor(api.search,q=username +'-filter:retweets',lang="en",since='2018-03-01').items()
        for tweet in tweets:
            Unlabled_Raw_tweet.append([username,tweet.id_str,tweet.created_at, tweet.text.encode("utf-8")])      
            parsed_tweet = {}
            parsed_tweet['text'] = tweet.text
            parsed_tweet['sentiment'] = get_tweet_sentiment(tweet.text)
            if tweet.retweet_count > 0:
                if parsed_tweet not in Labled_tweet:
                    Labled_tweet.append(parsed_tweet)
            else:
                Labled_tweet.append(parsed_tweet)  
        return Labled_tweet

# %%
username = ['@HemantSorenJMM','@drajoykumar','@dasraghubar']

for x in username:
        total_tweets = get_tweets(x)
        print("\nAnalysis Report of User ",x)
        positive_tweets = [tweet for tweet in total_tweets if tweet['sentiment'] == 'positive']
        print("\nPositive tweets percentage: {} %".format(100*len(positive_tweets)/len(total_tweets)))
        negative_tweets = [tweet for tweet in total_tweets if tweet['sentiment'] == 'negative']
        print("Negative tweets percentage: {} %".format(100*len(negative_tweets)/len(total_tweets)))
        print("Neutral tweets percentage: {} %".format(100*(len(total_tweets) - len(negative_tweets) - len(positive_tweets))/len(total_tweets)))
        """print("\n\nPositive tweets:")
        for tweet in positive_tweets[:10]:
            print(tweet['text']) 
            print("\n\nNegative tweets:")
        for tweet in negative_tweets[:10]:
            print(tweet['text
            outfile = x + "_tweets.csv"
        with open(outfile, 'w+') as file:
            writer = csv.writer(file, delimiter=',')
            writer.writerows(total_tweets)
            """

# %%
Final Clubbed Code

# %%
class Twitter_Account(object):
    
    def __init__(self):
        CONSUMER_KEY = 'L2UvKGZtWrAeQAibbuk3I6Yjt'
        CONSUMER_SECRET = 'RzyZZw4FCdokahW3Ft9xRAHXdEV2McAvafm50M7fLnM1xy8mIs'
        ACCESS_TOKEN = '3029741363-kJvrtCFpziKBIM1PsAd7wiRREHl7vwhBAlM10yB'
        ACCESS_TOKEN_SECRET = 'hkolCNEKvMFYj97YqwZsNvVP4zEhPfqVGfFv54C4Nv5aC'

        try: 
            auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
            auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
            api = tw.API(auth, wait_on_rate_limit=True)
        except: 
            print("Error: Authentication Failed") 

    #Function T CLean the Tweet Obtained
    def clean_tweet(tweet):
    #print("CLEANED TWEET = ",' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()))
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

    #Function to Get the Sentiment of the Tweet Obtained 
    def get_tweet_sentiment(tweet):
        analysis = TextBlob(clean_tweet(tweet))
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'

    #Function to Get the Tweet using the Name Given    
    def get_tweets(self,username):
        Labled_tweet = []
        Unlabled_Raw_tweet = []
        tweets = tw.Cursor(api.search,q=username +'-filter:retweets',lang="en",since='2018-03-01').items()
        for tweet in tweets:
            Unlabled_Raw_tweet.append([username,tweet.id_str,tweet.created_at, tweet.text.encode("utf-8")])      
            parsed_tweet = {}
            parsed_tweet['text'] = tweet.text
            parsed_tweet['sentiment'] = get_tweet_sentiment(tweet.text)
            if tweet.retweet_count > 0:
                if parsed_tweet not in Labled_tweet:
                    Labled_tweet.append(parsed_tweet)
            else:
                Labled_tweet.append(parsed_tweet)  
        return Labled_tweet      


def main():
    class_object = Twitter_Account()
    username = ['@HemantSorenJMM','@drajoykumar','@dasraghubar']
    for x in username:
        total_tweets = class_object.get_tweets(x)
        print("\nAnalysis Report of User ",x)
        positive_tweets = [tweet for tweet in total_tweets if tweet['sentiment'] == 'positive']
        print("\nPositive tweets percentage: {} %".format(100*len(positive_tweets)/len(total_tweets)))
        negative_tweets = [tweet for tweet in total_tweets if tweet['sentiment'] == 'negative']
        print("Negative tweets percentage: {} %".format(100*len(negative_tweets)/len(total_tweets)))
        print("Neutral tweets percentage: {} %".format(100*(len(total_tweets) - len(negative_tweets) - len(positive_tweets))/len(total_tweets)))
        """print("\n\nPositive tweets:")
        for tweet in positive_tweets[:10]:
            print(tweet['text']) 
            print("\n\nNegative tweets:")
        for tweet in negative_tweets[:10]:
            print(tweet['text
            outfile = x + "_tweets.csv"
        with open(outfile, 'w+') as file:
            writer = csv.writer(file, delimiter=',')
            writer.writerows(total_tweets)
             """
if __name__ == "__main__":
    main()
